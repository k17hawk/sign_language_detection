# %%
import os
os.chdir("../")

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class PrepareCallbacksConfig:
    root_dir: Path
    tensorboard_root_log_dir: Path
    checkpoint_model_filepath: Path

# %%
from ASL_alphabet.constants import *
from ASL_alphabet.utils import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])

    def get_prepare_callback_config(self) -> PrepareCallbacksConfig:
        config = self.config.prepare_callbacks
        model_ckpt_dir = os.path.dirname(config.checkpoint_model_filepath)
        create_directories([
            Path(model_ckpt_dir),
            Path(config.tensorboard_root_log_dir)
        ])

        prepare_callback_config = PrepareCallbacksConfig(
            root_dir=Path(config.root_dir),
            tensorboard_root_log_dir=Path(config.tensorboard_root_log_dir),
            checkpoint_model_filepath=Path(config.checkpoint_model_filepath)
        )

        return prepare_callback_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
import time

class PrepareCallback:
    def __init__(self, config: PrepareCallbacksConfig):
        self.config = config

    # @property
    # def _create_tb_callbacks(self):
    #     timestamp = time.strftime("%Y-%m-%d-%H-%M-%S")
    #     tb_running_log_dir = os.path.join(
    #         self.config.tensorboard_root_log_dir,
    #         f"tb_logs_at_{timestamp}",
    #     )
    #     return tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)

    # @property
    # def _create_ckpt_callbacks(self):
    #     return tf.keras.callbacks.ModelCheckpoint(
    #         filepath=self.config.checkpoint_model_filepath,
    #         save_best_only=True
    #     )
    @property
    def _create_tensorboard_callback(self):
        tb_running_log_dir = os.path.join(self.config.tensorboard_root_log_dir,time.strftime("%Y%m%d-%H%M%S"))
        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)
        return tensorboard_callback
    

    @property
    def _create_ckpt_callbacks(self):
        checkpoint_model_filepath = str(self.config.checkpoint_model_filepath)  # Convert to string if it's a PosixPath object
        
        return tf.keras.callbacks.ModelCheckpoint(
                filepath=checkpoint_model_filepath, 
                save_best_only=True
            )
         
    def get_tb_ckpt_callbacks(self):
        return [
            self._create_tensorboard_callback,
            self._create_ckpt_callbacks
        ]

# %%
# def create_tensorboard_callback(self):
#     tb_running_log_dir = os.path.join(self.config.tensorboard_root_log_dir,datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
#     tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)
#     return tensorboard_callback

# %%
try:
    config = ConfigurationManager()
    prepare_callbacks_config = config.get_prepare_callback_config()
    prepare_callbacks = PrepareCallback(config=prepare_callbacks_config)
    callback_list = prepare_callbacks.get_tb_ckpt_callbacks()
    
except Exception as e:
    raise e
# Out:
# [2023-07-11 14:21:00,431: INFO: utility]: yaml file: configs/config.yaml loaded successfully
# [2023-07-11 14:21:00,433: INFO: utility]: yaml file: params.yaml loaded successfully
# [2023-07-11 14:21:00,434: INFO: utility]: created directory at: artifacts
# [2023-07-11 14:21:00,435: INFO: utility]: created directory at: artifacts/prepare_callbacks/checkpoint_dir
# [2023-07-11 14:21:00,435: INFO: utility]: created directory at: artifacts/prepare_callbacks/tensorboard_log_dir

# %%
import tensorrt
print(tensorrt.__version__)
# Out:
# 8.6.1

# %%
#W!pip install tensorrt-8.6.1-py2.py3-none-any.whl 
#pip3 install tensorrt-8.6.1-py2.py3-none-any.whl
# Out:
# /bin/bash: /home/lang_chain/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Requirement 'tensorrt-8.6.1-py2.py3-none-any.whl' looks like a filename, but the file does not exist
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Processing ./tensorrt-8.6.1-py2.py3-none-any.whl
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/home/lang_chain/Documents/ASL_alphabet/tensorrt-8.6.1-py2.py3-none-any.whl'

# %%
#!pip install pycuda
# Out:
# /bin/bash: /home/lang_chain/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting pycuda
#   Downloading pycuda-2022.2.2.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytools>=2011.2 (from pycuda)
#   Downloading pytools-2023.1-py2.py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 87.5 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: appdirs>=1.4.0 in ./.venv/lib/python3.8/site-packages (from pycuda) (1.4.4)
# Collecting mako (from pycuda)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: platformdirs>=2.2.0 in ./.venv/lib/python3.8/site-packages (from pytools>=2011.2->pycuda) (3.8.1)
# Requirement already satisfied: typing-extensions>=4.0 in ./.venv/lib/python3.8/site-packages (from pytools>=2011.2->pycuda) (4.5.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in ./.venv/lib/python3.8/site-packages (from mako->pycuda) (2.1.3)
# Building wheels for collected packages: pycuda
#   Building wheel for pycuda (pyproject.toml) ... done
#   Created wheel for pycuda: filename=pycuda-2022.2.2-cp38-cp38-linux_x86_64.whl size=663312 sha256=f8b1a4eafe736aee43eca452b1e0cdc67aa9e30480ce6d632116baf105ceaaf9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ea_1dazb/wheels/7b/41/0d/7cecb04af969d283ebe4a69579a8b2baec0d010a1ac4159f7e
# Successfully built pycuda
# Installing collected packages: pytools, mako, pycuda
# Successfully installed mako-1.2.4 pycuda-2022.2.2 pytools-2023.1

# %%
#pip install deeplabcut[gui]
# Out:
# /bin/bash: /home/lang_chain/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting deeplabcut[gui]
#   Downloading deeplabcut-2.3.5-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Collecting dlclibrary (from deeplabcut[gui])
#   Downloading dlclibrary-0.0.3-py3-none-any.whl (14 kB)
# Collecting filterpy>=1.4.4 (from deeplabcut[gui])
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ruamel.yaml>=0.15.0 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (0.17.32)
# Collecting imgaug>=0.4.0 (from deeplabcut[gui])
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 822.0 kB/s eta 0:00:00a 0:00:01
# Collecting imageio-ffmpeg (from deeplabcut[gui])
#   Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 6.3 MB/s eta 0:00:0000:0100:01m
# Collecting numba>=0.54 (from deeplabcut[gui])
#   Downloading numba-0.57.1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 5.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib>=3.3 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (3.7.2)
# Requirement already satisfied: networkx>=2.6 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (3.1)
# Requirement already satisfied: numpy>=1.18.5 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (1.24.3)
# Requirement already satisfied: pandas!=1.5.0,>=1.0.1 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (2.0.3)
# Collecting scikit-image>=0.17 (from deeplabcut[gui])
#   Downloading scikit_image-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 7.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn>=1.0 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (1.3.0)
# Requirement already satisfied: scipy>=1.4 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (1.10.1)
# Collecting statsmodels>=0.11 (from deeplabcut[gui])
#   Downloading statsmodels-0.14.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 8.5 MB/s eta 0:00:0000:010:01m
# Collecting tables>=3.7.0 (from deeplabcut[gui])
#   Downloading tables-3.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting torch<=1.12 (from deeplabcut[gui])
#   Downloading torch-1.12.0-cp38-cp38-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 7.3 MB/s eta 0:00:0000:0100:03
# Collecting tensorpack>=0.11 (from deeplabcut[gui])
#   Downloading tensorpack-0.11-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 14.5 MB/s eta 0:00:00
# Collecting tf-slim>=1.1.0 (from deeplabcut[gui])
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (4.65.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (6.0)
# Requirement already satisfied: Pillow>=7.1 in ./.venv/lib/python3.8/site-packages (from deeplabcut[gui]) (10.0.0)
# Collecting pyside6<6.3.2 (from deeplabcut[gui])
#   Downloading PySide6-6.3.1-cp36-abi3-manylinux_2_28_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.6 MB/s eta 0:00:00
# Collecting qdarkstyle==3.1 (from deeplabcut[gui])
#   Downloading QDarkStyle-3.1-py2.py3-none-any.whl (870 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.2/870.2 kB 10.4 MB/s eta 0:00:00a 0:00:01
# Collecting napari-deeplabcut>=0.0.9 (from deeplabcut[gui])
#   Downloading napari_deeplabcut-0.1.2-py3-none-any.whl (31 kB)
# Collecting qtpy>=1.9 (from qdarkstyle==3.1->deeplabcut[gui])
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: six in ./.venv/lib/python3.8/site-packages (from imgaug>=0.4.0->deeplabcut[gui]) (1.16.0)
# Collecting opencv-python (from imgaug>=0.4.0->deeplabcut[gui])
#   Downloading opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 8.7 MB/s eta 0:00:0000:0100:01m
# Collecting imageio (from imgaug>=0.4.0->deeplabcut[gui])
#   Downloading imageio-2.31.1-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 16.7 MB/s eta 0:00:00
# Collecting Shapely (from imgaug>=0.4.0->deeplabcut[gui])
#   Downloading shapely-2.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.8/site-packages (from matplotlib>=3.3->deeplabcut[gui]) (6.0.0)
# Collecting dask-image (from napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading dask_image-2023.3.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 36.1 MB/s eta 0:00:00
# Collecting napari==0.4.17 (from napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading napari-0.4.17-py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 9.3 MB/s eta 0:00:00a 0:00:01m
# Collecting natsort (from napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Collecting opencv-python-headless (from napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 9.0 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: appdirs>=1.4.4 in ./.venv/lib/python3.8/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (1.4.4)
# Collecting app-model<0.3.0,>=0.0.8 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading app_model-0.1.4-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 19.8 MB/s eta 0:00:00
# Collecting cachey>=0.2.1 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading cachey-0.2.1-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: certifi>=2018.1.18 in ./.venv/lib/python3.8/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (2023.5.7)
# Collecting dask[array]!=2.28.0,>=2.15.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading dask-2023.5.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jsonschema>=3.2.0 in ./.venv/lib/python3.8/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (4.18.0)
# Collecting magicgui>=0.3.6 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading magicgui-0.7.2-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 12.5 MB/s eta 0:00:00
# Collecting napari-console>=0.0.6 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading napari_console-0.0.8-py3-none-any.whl (7.9 kB)
# Collecting napari-plugin-engine>=0.1.9 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading napari_plugin_engine-0.2.0-py3-none-any.whl (33 kB)
# Collecting napari-svg>=0.1.6 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading napari_svg-0.1.10-py3-none-any.whl (13 kB)
# Collecting npe2>=0.5.2 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading npe2-0.7.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 13.9 MB/s eta 0:00:00
# Collecting numpydoc>=0.9.2 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading numpydoc-1.5.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 16.4 MB/s eta 0:00:00
# Collecting pint>=0.17 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading Pint-0.21.1-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.8/290.8 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0 in ./.venv/lib/python3.8/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (5.9.5)
# Collecting psygnal>=0.3.4 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading psygnal-0.9.1-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 6.5 MB/s eta 0:00:00
# Collecting pydantic>=1.9.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading pydantic-2.0.2-py3-none-any.whl (359 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.1/359.1 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.8/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (2.15.1)
# Collecting PyOpenGL>=3.1.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.7 MB/s eta 0:00:00a 0:00:01m
# Collecting sphinx<5 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading Sphinx-4.5.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 8.0 MB/s eta 0:00:0000:0100:01m
# Collecting superqt>=0.3.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading superqt-0.4.1-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 16.9 MB/s eta 0:00:00
# Collecting tifffile>=2020.2.16 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading tifffile-2023.7.10-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 16.7 MB/s eta 0:00:00
# Collecting toolz>=0.10.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 146.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.8/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (4.5.0)
# Collecting vispy<0.12,>=0.11.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading vispy-0.11.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.6 MB/s eta 0:00:00a 0:00:01m
# Requirement already satisfied: wrapt>=1.11.1 in ./.venv/lib/python3.8/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (1.15.0)
# Collecting llvmlite<0.41,>=0.40.0dev0 (from numba>=0.54->deeplabcut[gui])
#   Downloading llvmlite-0.40.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 6.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: importlib-metadata in ./.venv/lib/python3.8/site-packages (from numba>=0.54->deeplabcut[gui]) (6.8.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas!=1.5.0,>=1.0.1->deeplabcut[gui]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.8/site-packages (from pandas!=1.5.0,>=1.0.1->deeplabcut[gui]) (2023.3)
# Collecting shiboken6==6.3.1 (from pyside6<6.3.2->deeplabcut[gui])
#   Downloading shiboken6-6.3.1-cp36-abi3-manylinux_2_28_x86_64.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.5/227.5 kB 6.0 MB/s eta 0:00:00a 0:00:01
# Collecting PySide6-Essentials==6.3.1 (from pyside6<6.3.2->deeplabcut[gui])
#   Downloading PySide6_Essentials-6.3.1-cp36-abi3-manylinux_2_28_x86_64.whl (76.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 8.3 MB/s eta 0:00:0000:0100:01
# Collecting PySide6-Addons==6.3.1 (from pyside6<6.3.2->deeplabcut[gui])
#   Downloading PySide6_Addons-6.3.1-cp36-abi3-manylinux_2_28_x86_64.whl (120.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.1/120.1 MB 11.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in ./.venv/lib/python3.8/site-packages (from ruamel.yaml>=0.15.0->deeplabcut[gui]) (0.2.7)
# Collecting PyWavelets>=1.1.1 (from scikit-image>=0.17->deeplabcut[gui])
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 9.9 MB/s eta 0:00:0000:01:00:01
# Collecting lazy_loader>=0.2 (from scikit-image>=0.17->deeplabcut[gui])
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.8/site-packages (from scikit-learn>=1.0->deeplabcut[gui]) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.8/site-packages (from scikit-learn>=1.0->deeplabcut[gui]) (3.1.0)
# Collecting patsy>=0.5.2 (from statsmodels>=0.11->deeplabcut[gui])
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 18.3 MB/s eta 0:00:00
# Collecting cython>=0.29.21 (from tables>=3.7.0->deeplabcut[gui])
#   Downloading Cython-0.29.36-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 13.1 MB/s eta 0:00:00a 0:00:01
# Collecting numexpr>=2.6.2 (from tables>=3.7.0->deeplabcut[gui])
#   Downloading numexpr-2.8.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 5.2 MB/s eta 0:00:00a 0:00:01
# Collecting blosc2~=2.0.0 (from tables>=3.7.0->deeplabcut[gui])
#   Downloading blosc2-2.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 9.6 MB/s eta 0:00:00a 0:00:01m
# Collecting py-cpuinfo (from tables>=3.7.0->deeplabcut[gui])
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: termcolor>=1.1 in ./.venv/lib/python3.8/site-packages (from tensorpack>=0.11->deeplabcut[gui]) (2.3.0)
# Requirement already satisfied: tabulate>=0.7.7 in ./.venv/lib/python3.8/site-packages (from tensorpack>=0.11->deeplabcut[gui]) (0.9.0)
# Collecting msgpack>=0.5.2 (from tensorpack>=0.11->deeplabcut[gui])
#   Downloading msgpack-1.0.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 kB 11.0 MB/s eta 0:00:00
# Collecting msgpack-numpy>=0.4.4.2 (from tensorpack>=0.11->deeplabcut[gui])
#   Downloading msgpack_numpy-0.4.8-py2.py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pyzmq>=16 in ./.venv/lib/python3.8/site-packages (from tensorpack>=0.11->deeplabcut[gui]) (25.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in ./.venv/lib/python3.8/site-packages (from tf-slim>=1.1.0->deeplabcut[gui]) (1.4.0)
# Collecting huggingface-hub (from dlclibrary->deeplabcut[gui])
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3->deeplabcut[gui]) (3.16.0)
# Collecting pims>=0.4.1 (from dask-image->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading PIMS-0.6.1.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 41.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in ./.venv/lib/python3.8/site-packages (from huggingface-hub->dlclibrary->deeplabcut[gui]) (3.12.2)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.8/site-packages (from huggingface-hub->dlclibrary->deeplabcut[gui]) (2023.6.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.8/site-packages (from huggingface-hub->dlclibrary->deeplabcut[gui]) (2.31.0)
# Collecting in-n-out>=0.1.5 (from app-model<0.3.0,>=0.0.8->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading in_n_out-0.1.8-py3-none-any.whl (19 kB)
# Collecting pydantic>=1.9.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading pydantic-1.10.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 8.2 MB/s eta 0:00:00a 0:00:01m
# Collecting heapdict (from cachey>=0.2.1->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: click>=8.0 in ./.venv/lib/python3.8/site-packages (from dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (8.1.4)
# Collecting cloudpickle>=1.5.0 (from dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting partd>=1.2.0 (from dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading partd-1.4.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.8/site-packages (from jsonschema>=3.2.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.8/site-packages (from jsonschema>=3.2.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (2023.6.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./.venv/lib/python3.8/site-packages (from jsonschema>=3.2.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.8/site-packages (from jsonschema>=3.2.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.29.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.8/site-packages (from jsonschema>=3.2.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.8.10)
# Collecting docstring-parser>=0.7 (from magicgui>=0.3.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: ipykernel>=5.2.0 in ./.venv/lib/python3.8/site-packages (from napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (6.24.0)
# Requirement already satisfied: IPython>=7.7.0 in ./.venv/lib/python3.8/site-packages (from napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (8.12.2)
# Collecting qtconsole!=4.7.6,!=5.4.2,>=4.5.1 (from napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 13.4 MB/s eta 0:00:00
# Collecting build (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading build-0.10.0-py3-none-any.whl (17 kB)
# Collecting pytomlpp (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading pytomlpp-1.0.13-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: rich in ./.venv/lib/python3.8/site-packages (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (13.4.2)
# Collecting typer (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.10 in ./.venv/lib/python3.8/site-packages (from numpydoc>=0.9.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (3.1.2)
# Collecting slicerator>=0.9.8 (from pims>=0.4.1->dask-image->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading slicerator-1.1.0-py3-none-any.whl (10 kB)
# Collecting mypy-extensions (from psygnal>=0.3.4->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting sphinxcontrib-applehelp (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading sphinxcontrib_applehelp-1.0.4-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 kB 23.1 MB/s eta 0:00:00
# Collecting sphinxcontrib-devhelp (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 26.3 MB/s eta 0:00:00
# Collecting sphinxcontrib-jsmath (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading sphinxcontrib_htmlhelp-2.0.1-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.8/99.8 kB 29.1 MB/s eta 0:00:00
# Collecting sphinxcontrib-serializinghtml>=1.1.5 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 17.9 MB/s eta 0:00:00
# Collecting sphinxcontrib-qthelp (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 9.2 MB/s eta 0:00:00
# Collecting docutils<0.18,>=0.14 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.5/575.5 kB 16.2 MB/s eta 0:00:00a 0:00:01
# Collecting snowballstemmer>=1.1 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 19.0 MB/s eta 0:00:00
# Collecting babel>=1.3 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading Babel-2.12.1-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 6.5 MB/s eta 0:00:000:0100:01m
# Collecting alabaster<0.8,>=0.7 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading alabaster-0.7.13-py3-none-any.whl (13 kB)
# Collecting imagesize (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests->huggingface-hub->dlclibrary->deeplabcut[gui]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests->huggingface-hub->dlclibrary->deeplabcut[gui]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.8/site-packages (from requests->huggingface-hub->dlclibrary->deeplabcut[gui]) (1.26.16)
# Collecting freetype-py (from vispy<0.12,>=0.11.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading freetype_py-2.4.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.2 MB/s eta 0:00:00ta 0:00:01
# Collecting hsluv (from vispy<0.12,>=0.11.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading hsluv-5.0.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.1.6)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.8/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (5.9.0)
# Requirement already satisfied: backcall in ./.venv/lib/python3.8/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.2.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.8/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.8/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.18.2)
# Requirement already satisfied: pickleshare in ./.venv/lib/python3.8/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./.venv/lib/python3.8/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (3.0.39)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.8/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.8/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.8/site-packages (from Jinja2>=2.10->numpydoc>=0.9.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (2.1.3)
# Collecting locket (from partd>=1.2.0->dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: ipython-genutils in ./.venv/lib/python3.8/site-packages (from qtconsole!=4.7.6,!=5.4.2,>=4.5.1->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.2.0)
# Collecting pyproject_hooks (from build->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting tomli>=1.1.0 (from build->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui])
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.8/site-packages (from rich->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (3.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./.venv/lib/python3.8/site-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (3.8.1)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.8/site-packages (from pexpect>4.3->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.8/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.8/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (2.2.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.8/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut[gui]) (0.2.2)
# Building wheels for collected packages: filterpy, pims
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110449 sha256=b1908620db06cd105b69f08ba654262212739cf43d10a933bf5888955c61a364
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jn1qghw2/wheels/fe/f6/cb/40331472edf4fd399b8cad02973c6acbdf26898342928327fe
#   Building wheel for pims (setup.py) ... done
#   Created wheel for pims: filename=PIMS-0.6.1-py3-none-any.whl size=82636 sha256=91a671480696ad08d6e43ab1ca6f548f979fea91921184956fc2d3ea5bfbfb97
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jn1qghw2/wheels/5c/bd/a9/9cede777cb4fcdd2ba712cdb0d0c9082aba544322eb5ad7af1
# Successfully built filterpy pims
# Installing collected packages: snowballstemmer, slicerator, pytomlpp, PyOpenGL, py-cpuinfo, msgpack, heapdict, typer, torch, toolz, tomli, tifffile, tf-slim, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, shiboken6, Shapely, qtpy, PyWavelets, pydantic, pint, patsy, opencv-python-headless, opencv-python, numexpr, natsort, napari-plugin-engine, mypy-extensions, msgpack-numpy, locket, llvmlite, lazy_loader, in-n-out, imagesize, imageio-ffmpeg, imageio, hsluv, freetype-py, docutils, docstring-parser, cython, cloudpickle, cachey, blosc2, babel, alabaster, vispy, tensorpack, tables, superqt, sphinx, scikit-image, qdarkstyle, PySide6-Essentials, pyproject_hooks, psygnal, pims, partd, numba, huggingface-hub, statsmodels, PySide6-Addons, numpydoc, napari-svg, magicgui, imgaug, filterpy, dlclibrary, dask, build, app-model, pyside6, npe2, deeplabcut, qtconsole, dask-image, napari-console, napari, napari-deeplabcut
# Successfully installed PyOpenGL-3.1.7 PySide6-Addons-6.3.1 PySide6-Essentials-6.3.1 PyWavelets-1.4.1 Shapely-2.0.1 alabaster-0.7.13 app-model-0.1.4 babel-2.12.1 blosc2-2.0.0 build-0.10.0 cachey-0.2.1 cloudpickle-2.2.1 cython-0.29.36 dask-2023.5.0 dask-image-2023.3.0 deeplabcut-2.3.5 dlclibrary-0.0.3 docstring-parser-0.15 docutils-0.17.1 filterpy-1.4.5 freetype-py-2.4.0 heapdict-1.0.1 hsluv-5.0.3 huggingface-hub-0.16.4 imageio-2.31.1 imageio-ffmpeg-0.4.8 imagesize-1.4.1 imgaug-0.4.0 in-n-out-0.1.8 lazy_loader-0.3 llvmlite-0.40.1 locket-1.0.0 magicgui-0.7.2 msgpack-1.0.5 msgpack-numpy-0.4.8 mypy-extensions-1.0.0 napari-0.4.17 napari-console-0.0.8 napari-deeplabcut-0.1.2 napari-plugin-engine-0.2.0 napari-svg-0.1.10 natsort-8.4.0 npe2-0.7.0 numba-0.57.1 numexpr-2.8.4 numpydoc-1.5.0 opencv-python-4.8.0.74 opencv-python-headless-4.8.0.74 partd-1.4.0 patsy-0.5.3 pims-0.6.1 pint-0.21.1 psygnal-0.9.1 py-cpuinfo-9.0.0 pydantic-1.10.11 pyproject_hooks-1.0.0 pyside6-6.3.1 pytomlpp-1.0.13 qdarkstyle-3.1 qtconsole-5.4.3 qtpy-2.3.1 scikit-image-0.21.0 shiboken6-6.3.1 slicerator-1.1.0 snowballstemmer-2.2.0 sphinx-4.5.0 sphinxcontrib-applehelp-1.0.4 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 statsmodels-0.14.0 superqt-0.4.1 tables-3.8.0 tensorpack-0.11 tf-slim-1.1.0 tifffile-2023.7.10 tomli-2.0.1 toolz-0.12.0 torch-1.12.0 typer-0.9.0 vispy-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install tensorrt
# Out:
# /bin/bash: /home/lang_chain/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting tensorrt
#   Downloading tensorrt-8.6.1.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: tensorrt
#   Building wheel for tensorrt (setup.py) ... done
#   Created wheel for tensorrt: filename=tensorrt-8.6.1-py2.py3-none-any.whl size=16968 sha256=0e2ccf6ac98975ad29a834eb3084ffc73b4e042f1336bca0ac6349f1ec272499
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7hxfh902/wheels/64/1e/cf/07658918aa1882ccc963fa6ecc0870106559f8cd7c0271e966
# Successfully built tensorrt
# Installing collected packages: tensorrt
# Successfully installed tensorrt-8.6.1

# %%
import tensorflow as tf
# Solves Convolution CuDNN error
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# 2023-07-11 10:27:51.569802: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-11 10:27:51.600361: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-11 10:27:51.600649: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
